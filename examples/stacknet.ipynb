# %%
# !pip install ../.

# %%
import os
import subprocess
import numpy as np
import pandas as pd

from pystacknet import StackNetClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
DATA_HOME = "/Users/elejke/data"
STACKNET_HOME = "/Users/elejke/Dropbox/Kaggle/StackNet"

# %%
X, y = load_iris(True)

# %%
X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.3, random_state=2017, stratify=y)

# %%
clf_stacknet = StackNetClassifier(n_folds=3, n_jobs=10, data_home=DATA_HOME, stacknet_home=STACKNET_HOME)

# %%
clf_stacknet.fit(X_tr, y_tr)
# Out:
# StackNetClassifier(data_home='/Users/elejke/data', metric='logloss',
#           n_folds=3, n_jobs=10, params_file=None, random_state=2017,
#           stack_data=False,
#           stacknet_home='/Users/elejke/Dropbox/Kaggle/StackNet',
#           test_file='test_stacknet.csv', train_file='train_stacknet.csv',
#           verbose=True)
# StackNetClassifier(data_home='/Users/elejke/data', metric='logloss',
#           n_folds=3, n_jobs=10, params_file=None, random_state=2017,
#           stack_data=False,
#           stacknet_home='/Users/elejke/Dropbox/Kaggle/StackNet',
#           test_file='test_stacknet.csv', train_file='train_stacknet.csv',
#           verbose=True)

# %%
y_proba_stacknet = clf_stacknet.predict_proba(X_te)
# Out:
# parameter name : task value :  classification
# parameter name : train_file value :  /users/elejke/data/train_stacknet.csv
# parameter name : test_file value :  /users/elejke/data/test_stacknet.csv
# parameter name : model_file value :  /users/elejke/dropbox/kaggle/stacknet/stacknet.model
# parameter name : params value :  params.txt
# parameter name : test_target value :  false
# parameter name : pred_file value :  /users/elejke/dropbox/kaggle/stacknet/stacknet_pred.csv
# parameter name : verbose value :  true
# parameter name : threads value :  10
# parameter name : stackdata value :  false
# parameter name : folds value :  3
# parameter name : seed value :  2017
# parameter name : metric value :  logloss
#  Completed: 4.76 %
#  Completed: 9.52 %
#  Completed: 14.29 %
#  Completed: 19.05 %
#  Completed: 23.81 %
#  Completed: 28.57 %
#  Completed: 33.33 %
#  Completed: 38.10 %
#  Completed: 42.86 %
#  Completed: 47.62 %
#  Completed: 52.38 %
#  Completed: 57.14 %
# ...

# %%
accuracy_score(y_te, np.argmax(y_proba_stacknet, axis=1))
# Out:
# 0.8666666666666667
# 0.8666666666666667

# %%
accuracy_score(y_te, LogisticRegression().fit(X_tr, y_tr).predict(X_te))
# Out:
# 0.9333333333333333
# 0.9333333333333333
